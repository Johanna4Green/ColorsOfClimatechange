# %%
import numpy as np
import pandas as pd 
import PIL as pil
import cv2
from sklearn import cluster
import seaborn as sn 
import os
import re
import matplotlib.pyplot as plt

import time
import math
import colorsys

# %%
def import_file_names(hashtags, image_directories, image_name_files, platform):
    df_filenames = pd.DataFrame(columns=["id", "platform", "hashtag", "filepath"])
    if platform == "instagram":
        #code for extracting a unique identifier from instagram urls.
        #will get replaced once I have downloaded the updated data.
        uuid_pattern = re.compile(r"https://www.instagram.com/\w*/(.*)/")
        for hashtag in hashtags:
            df_hashtag_filenames = pd.read_csv(image_name_files[hashtag], delimiter=",")
            for idx, row in df_hashtag_filenames.iterrows():
                filepath = image_directories[hashtag] + str(row["Id"])
                uuid = row["Id"]
                #print(idx,uuid, filepath)
                df_filenames = pd.concat([pd.DataFrame([[uuid, platform, hashtag, filepath]], columns=df_filenames.columns), df_filenames])
    if platform == "tiktok":

        for hashtag in hashtags:
            df_hashtag_filenames = pd.read_csv(image_name_files[hashtag], delimiter=",")
            for idx, row in df_hashtag_filenames.iterrows():
                uuid = row["id"]
                filepath = image_directories[hashtag] + str(uuid) + ".jpeg"
                #print(idx,uuid, filepath)
                df_filenames = pd.concat([pd.DataFrame([[uuid, platform, hashtag, filepath]], columns=df_filenames.columns), df_filenames])
            

    return df_filenames

# %% [markdown]
# **Für Instagram-Daten**

# %%
# reading in file paths
hashtags = ["climatechange", "climatecrisis", "savetheplanet", "klimakrise", "klimaschutz"]
image_directories = {
    "climatechange":"DATA\INSTA_DATA_COMPLETE\climatechange_images_names\\",
    "climatecrisis":"DATA\INSTA_DATA_COMPLETE\climatecrisis_images_names\\",
    "savetheplanet":"DATA\INSTA_DATA_COMPLETE\savetheplanet_images_names\\",
    "klimakrise":"DATA\INSTA_DATA_COMPLETE\klimakrise_images_names\\",
    "klimawandel":"DATA\INSTA_DATA_COMPLETE\klimawandel_images_names\\",
    "klimaschutz":"DATA\INSTA_DATA_COMPLETE\klimaschutz_images_names\\"
}

#CSVs where the filenames of images are saved
image_name_files = {
    "climatechange":"DATA\INSTA_DATA_COMPLETE\climatechange.csv",
    "climatecrisis":"DATA\INSTA_DATA_COMPLETE\climatecrisis.csv",
    "savetheplanet":"DATA\INSTA_DATA_COMPLETE\savetheplanet.csv",
    "klimakrise":"DATA\INSTA_DATA_COMPLETE\klimakrise.csv",
    "klimawandel":"DATA\INSTA_DATA_COMPLETE\klimawandel.csv",
    "klimaschutz":"DATA\INSTA_DATA_COMPLETE\klimaschutz.csv"

}

df_image_filepaths_instagram = import_file_names(hashtags, image_directories, image_name_files, "instagram")

# %% [markdown]
# **Für Tiktok-Daten**

# %%
#reading in file paths
hashtags = ["climatechange", "climatecrisis", "savetheplanet", "klimakrise", "klimaschutz"]
image_directories = {
    "climatechange":"DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\\",
    "climatecrisis":"DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\\",
    "savetheplanet":"DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\\",
    "klimakrise":"DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\\",
    "klimawandel":"DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimawandel\klimawandel Bilder Philipp und Annika\\",
    "klimaschutz":"DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimaschutz\klimaschutz Bilder Philipp und Annika\\"
}

image_name_files = {
    "climatechange":"DATA\Daten TikTok gemerged\Tiktok csv gemerged\climatechange\column-filter-4c19b73d2271ac697cb14e7085f182dc.csv",
    "climatecrisis":"DATA\Daten TikTok gemerged\Tiktok csv gemerged\climatecrisis\column-filter-ac7e6b48b705b231a6d0677de468caa0(1).csv",
    "savetheplanet":"DATA\Daten TikTok gemerged\Tiktok csv gemerged\savetheplanet\column-filter-26348f885172ba823820df8ab3e1a1de.csv",
    "klimakrise":"DATA\Daten TikTok gemerged\Tiktok csv gemerged\klimakrise\column-filter-a9851a7839f6530d133fe62f26b09c55.csv",
    "klimawandel":"DATA\Daten TikTok gemerged\Tiktok csv gemerged\klimawandel\column-filter-1b666f03e9a3d630c2e42d4c735f5100.csv",
    "klimaschutz":"DATA\Daten TikTok gemerged\Tiktok csv gemerged\klimaschutz\column-filter-9c0da9f64cf3bc4f77a724d098048b66.csv"

}

df_image_filepaths_tiktok = import_file_names(hashtags, image_directories, image_name_files, "tiktok")

# %%
df_image_filepaths = pd.concat([df_image_filepaths_instagram, df_image_filepaths_tiktok])
#only for testing purposes. Remove before processing the data for real.
#df_image_filepaths = df_image_filepaths.sample(25)
df_image_filepaths
# Out:
#                      id   platform        hashtag  \
# 0   klimaschutz_700.jpg  instagram    klimaschutz
# 0   klimaschutz_699.jpg  instagram    klimaschutz
# 0   klimaschutz_698.jpg  instagram    klimaschutz
# 0   klimaschutz_697.jpg  instagram    klimaschutz
# 0   klimaschutz_696.jpg  instagram    klimaschutz
# ..                  ...        ...            ...
# 0   7252904683222895918     tiktok  climatechange
# 0   7291671021827116334     tiktok  climatechange
# 0   7224978138751618305     tiktok  climatechange
# 0   7256810993311812907     tiktok  climatechange
# 0   7172368921318657322     tiktok  climatechange
#
#                                              filepath
# 0   DATA\INSTA_DATA_COMPLETE\klimaschutz_images_na...
# 0   DATA\INSTA_DATA_COMPLETE\klimaschutz_images_na...
# 0   DATA\INSTA_DATA_COMPLETE\klimaschutz_images_na...
# 0   DATA\INSTA_DATA_COMPLETE\klimaschutz_images_na...
# 0   DATA\INSTA_DATA_COMPLETE\klimaschutz_images_na...
# ..                                                ...
# 0   DATA\Daten TikTok gemerged\TikTok Bilder gemer...
# 0   DATA\Daten TikTok gemerged\TikTok Bilder gemer...
# 0   DATA\Daten TikTok gemerged\TikTok Bilder gemer...
# 0   DATA\Daten TikTok gemerged\TikTok Bilder gemer...
# 0   DATA\Daten TikTok gemerged\TikTok Bilder gemer...
#
# [5968 rows x 4 columns]

# %%
df_clusters = pd.DataFrame(columns = ["id", "platform", "hashtag", "r", "g", "b", "h", "s", "v", "relative_frequency"])

# %%
# constants
eps = 8 #for DBSCAN
max_eps = 18 #for OPTICS
num_colors = 5#for Kmeans
min_samples = 128

color_mode = "hsv"
#color_mode = "rgb"

visualize = False

do_remove_noise = False

scale_factor = 0.12
thumbnail_size = (128,128)

distance_thresh = 84 # for Agglomerative Clustering

# %%
def distance_hsv_colors(x,y):
    dist_hue = min(pow(x[0] - y[0], 2), pow((x[0]+128) % 256 - (y[0]+128) % 256, 2))
    dist_sat = pow(x[1] - y[1], 2)
    dist_val = pow(x[2] - y[2], 2)

    return math.sqrt(dist_hue + dist_sat + dist_val)

# %% [markdown]
# ### Clustering

# %%
total_num_rows = df_image_filepaths.shape[0]
num_rows = 0
for idx, row in df_image_filepaths.iterrows():
    num_rows+=1
    filepath = row["filepath"]
    try:
        with pil.Image.open(filepath) as img:
            #img = img.resize((math.floor(img.size[0]*scale_factor), math.floor(img.size[1]*scale_factor)))
            img.thumbnail(thumbnail_size)
            if color_mode == "hsv":
                img = img.convert('HSV')
            img_pixels = np.asarray(img).reshape(img.size[0]*img.size[1], 3)

            #DIFFERENT CLUSTERING ALGORITHMS - uncomment as needed.

            # K-MEANS: Simple, but limited. Only accepts a set number of clusters. 
            #model = cluster.KMeans(n_clusters=num_colors, n_init="auto")

            # DBSCAN: Good results and quite fast. Biggest drawback is its memory use (can be combatted by reducing image resolution.)
            model = cluster.DBSCAN(eps=eps,min_samples=min_samples)#, metric=distance_hsv_colors)

            #OPTICS: Similar to DBSCAN without the memory requirements, but very slow.
            #model = cluster.OPTICS(min_samples=min_samples, max_eps=max_eps)

            #Agglomerative: Returns clusters of relatively equal size, but difficult to control and slow.
            #model = cluster.AgglomerativeClustering(n_clusters=None, distance_threshold=distance_thresh, linkage='average')


            labels = model.fit_predict(img_pixels) 
            #print(labels)
            #model = cluster.BisectingKMeans(num_colors).fit(img_pixels)
            #centroids = model.cluster_centers_
            unique_labels, counts = np.unique(labels, return_counts=True)
            centroids = np.empty((unique_labels.shape[0], 3))
            for i, label in enumerate(unique_labels):
                #centroids[i] = img_pixels[labels == label].mean(axis=0)
                centroids[i] = np.median(img_pixels[labels == label], axis=0)
            
            if -1 in unique_labels and do_remove_noise:
                centroids = centroids[1:]
            #print(f"CENTROIDS: {centroids}")

            counts = counts / labels.shape[0]
            #print(counts, unique_labels)

            #visualization stuff
            if visualize:
                pie_colors = []
                for i, clr in enumerate(centroids):
                    pie_color = tuple(clr/255)
                    if color_mode == "hsv":
                        pie_color = colorsys.hsv_to_rgb(*pie_color)
                    pie_colors.append(pie_color)

                plt.imshow(img)
                plt.show()
                plt.pie(counts, colors=pie_colors)
                plt.show()
            # end visualization stuff

            for i, color in enumerate(centroids):
                if color_mode == "hsv":
                    h, s, v = tuple(color/255)
                    r, g, b = colorsys.hsv_to_rgb(h, s, v)
                elif color_mode == "rgb":
                    r, g, b = tuple(color/255)
                    h, s, v = colorsys.hsv_to_rgb(r, g, b)
                relative_frequency = counts[i]
                new_row = pd.DataFrame([[row["id"], row["platform"], row["hashtag"], r, g, b, h, s, v, relative_frequency]], columns=df_clusters.columns)
                if visualize:
                    print(new_row)
                df_clusters = pd.concat([new_row, df_clusters])
        
        if not visualize:
            print (f"\r {num_rows}/{total_num_rows}", end="")
    except FileNotFoundError as e:
        print(f"No File at {filepath}")
# Out:
#  3141/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimaschutz\klimaschutz Bilder Philipp und Annika\7115744451003206917.jpeg
#  3269/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimaschutz\klimaschutz Bilder Philipp und Annika\7285381694939565344.jpeg
#  3272/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimaschutz\klimaschutz Bilder Philipp und Annika\7218976919541288197.jpeg
#  3293/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimaschutz\klimaschutz Bilder Philipp und Annika\7268692536632380704.jpeg
#  3326/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimaschutz\klimaschutz Bilder Philipp und Annika\7180385660988148998.jpeg
#  3348/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimaschutz\klimaschutz Bilder Philipp und Annika\7241781385092943130.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimaschutz\klimaschutz Bilder Philipp und Annika\7244224754188619034.jpeg
#  3421/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimaschutz\klimaschutz Bilder Philipp und Annika\7211140481835617542.jpeg
#  3445/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimaschutz\klimaschutz Bilder Philipp und Annika\7164349531130285318.jpeg
#  3448/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimaschutz\klimaschutz Bilder Philipp und Annika\7295011292522319136.jpeg
#  3488/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimaschutz\klimaschutz Bilder Philipp und Annika\7218959611045399834.jpeg
#  3490/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimaschutz\klimaschutz Bilder Philipp und Annika\7161761185925565722.jpeg
#  3494/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimaschutz\klimaschutz Bilder Philipp und Annika\7162028329883684123.jpeg
#  3534/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimaschutz\klimaschutz Bilder Philipp und Annika\7283114456463265056.jpeg
#  3549/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimaschutz\klimaschutz Bilder Philipp und Annika\7246780693261323525.jpeg
#  3570/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimaschutz\klimaschutz Bilder Philipp und Annika\7220421720476372229.jpeg
#  3663/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimaschutz\klimaschutz Bilder Philipp und Annika\7266405938083400993.jpeg
#  3695/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7207761071711505669.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7018942126654360837.jpeg
#  3699/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7292372974345276704.jpeg
#  3710/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7152506388839714054.jpeg
#  3748/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7315668427413130529.jpeg
#  3763/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7303291132937620768.jpeg
#  3767/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7159916398834093318.jpeg
#  3778/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7162822338147323142.jpeg
#  3782/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7213722622297640198.jpeg
#  3785/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7091356707728805125.jpeg
#  3789/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7158790132563217670.jpeg
#  3822/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7195521600429624582.jpeg
#  3826/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7115744451003206917.jpeg
#  3852/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\6940240623349910790.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7295744141323980064.jpeg
#  3859/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7130563496814628102.jpeg
#  3878/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7220710459626802458.jpeg
#  3886/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7161070256956443910.jpeg
#  3891/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7158122510444219654.jpeg
#  3896/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\6834844494916013318.jpeg
#  3901/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\6959449902636076294.jpeg
#  3931/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7198417641197866246.jpeg
#  3938/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7272393660447100192.jpeg
#  3958/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7241781385092943130.jpeg
#  3963/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7160659288581541125.jpeg
#  4006/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7211140481835617542.jpeg
#  4041/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7231566842920242459.jpeg
#  4065/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7213682245427694853.jpeg
#  4093/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7196787586487028998.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7168380203192814853.jpeg
#  4103/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7207909879724428550.jpeg
#  4128/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7214023281391734022.jpeg
#  4143/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7004114906651823365.jpeg
#  4167/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7132421552913632517.jpeg
#  4172/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7273164501728415009.jpeg
#  4212/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7245352131761327387.jpeg
#  4220/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7001409444319874309.jpeg
#  4251/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7302750222063553825.jpeg
#  4285/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\klimakrise\Klimakrise Bilder philipp und annika\7154674178233208069.jpeg
#  4328/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6798548045739887877.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7034644508419820846.jpeg
#  4333/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6805310483814436102.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6981154606491372806.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7090391076770499846.jpeg
#  4337/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7106300279263366406.jpeg
#  4339/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7019717131298196741.jpeg
#  4350/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7119792216125508870.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6968856083913886981.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7031969378295909637.jpeg
#  4363/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6891215820039392513.jpeg
#  4366/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7120571308999478534.jpeg
#  4368/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6901985460491390209.jpeg
#  4370/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7122498002945707306.jpeg
#  4374/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6803008544380620038.jpeg
#  4376/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6927711649122028806.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6956341521688087813.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6952520497175284997.jpeg
#  4382/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7238424830989667590.jpeg
#  4385/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6862286165844724998.jpeg
#  4390/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6720604231868353798.jpeg
#  4392/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7242782376500202779.jpeg
#  4397/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7206639554844200197.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7185366335193435418.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6762880675138866437.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6975017228601232646.jpeg
#  4403/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7113650981199416581.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7081122725242129691.jpeg
#  4408/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7180460609841024298.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6814920270755745029.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7125093958388043014.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7087601801226194181.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6884612016175090945.jpeg
#  4415/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6885304998238883073.jpeg
#  4418/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6941415448281943302.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7188804963861105926.jpeg
#  4421/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7316511865083874592.jpeg
#  4423/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6866949255462997250.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7206805615685963013.jpeg
#  4426/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6866672785960307974.jpeg
#  4429/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6960609105140632838.jpeg
#  4433/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7095044768538905861.jpeg
#  4441/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7233821130522496283.jpeg
#  4444/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6763682086835555590.jpeg
#  4447/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6866578520504569090.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7133598853869096198.jpeg
#  4451/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7119922870867840261.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6940085752315383045.jpeg
#  4461/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7053586350263618863.jpeg
#  4465/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6957146083952758022.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7026152638316055814.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7036457335090515246.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7086861473443613957.jpeg
#  4470/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6944450617418976518.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6904714487350267142.jpeg
#  4473/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6995641186501364998.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6973640368088796421.jpeg
#  4477/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7146004292711845126.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7124392675683372293.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7051927224554949893.jpeg
#  4481/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6928076736726945030.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6960013922187431174.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7200215559294831914.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7206312128351898885.jpeg
#  4486/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7089210026182675717.jpeg
#  4490/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7094857131559554331.jpeg
#  4493/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6779262661809949958.jpeg
#  4496/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6984752152375774469.jpeg
#  4499/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6896563142009064706.jpeg
#  4504/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6719185192776387846.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6963187457982500101.jpeg
#  4513/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7203267230165929243.jpeg
#  4516/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6937378380048321798.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7211088605115141381.jpeg
#  4520/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6974403657873853701.jpeg
#  4531/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6713597341804268806.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6737660249458658565.jpeg
#  4534/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7086897101191367938.jpeg
#  4536/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7011984221979921669.jpeg
#  4539/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6944134181949541637.jpeg
#  4541/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6970657669501734149.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6797882603262201094.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7272948782570966278.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6798451861482474753.jpeg
#  4547/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6969896625615523074.jpeg
#  4551/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7203922805052738822.jpeg
#  4553/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6967675411455151366.jpeg
#  4557/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7054491015989710086.jpeg
#  4560/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6897702514741873921.jpeg
#  4565/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7010155054149815557.jpeg
#  4570/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6976789673737751814.jpeg
#  4575/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6728428437461110022.jpeg
#  4578/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6956610742103592198.jpeg
#  4580/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6771949008295316742.jpeg
#  4582/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6938919260093811974.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7073135153584868614.jpeg
#  4585/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6791226091664149765.jpeg
#  4587/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6872971753312881921.jpeg
#  4590/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7122437493160512773.jpeg
#  4593/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6976169906744167682.jpeg
#  4599/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7126165262964886790.jpeg
#  4605/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7029367555890384134.jpeg
#  4608/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7126134380162010373.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7296594375428246830.jpeg
#  4612/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7241279751627869445.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7061199163186253082.jpeg
#  4615/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6930638720592792837.jpeg
#  4618/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7007675948719934725.jpeg
#  4620/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6972174455015542022.jpeg
#  4629/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7087266825431469317.jpeg
#  4634/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7246313189405773062.jpeg
#  4640/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6959772909489392902.jpeg
#  4642/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6943388975281294598.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7060409222747475226.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7288121687860710662.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6940685050434325766.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6963940354232012037.jpeg
#  4649/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6995106296122952965.jpeg
#  4652/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6824157610971909382.jpeg
#  4655/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7205541380674882821.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6808299566526516485.jpeg
#  4661/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6850135085061131525.jpeg
#  4663/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6783861692427259141.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6840073279743495429.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6818940928573656325.jpeg
#  4668/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6733089677064113413.jpeg
#  4672/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6975141700872195333.jpeg
#  4675/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7260221757104065818.jpeg
#  4679/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7042683662176980230.jpeg
#  4685/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6959136353028295942.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7125985606970215722.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6942910899892079877.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6942596996553248006.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6937752050264509702.jpeg
#  4692/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6930783174314249478.jpeg
#  4694/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6997084355386445061.jpeg
#  4697/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6966935968393743621.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7189729662032006442.jpeg
#  4700/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6976827498529131782.jpeg
#  4702/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7173763906425523502.jpeg
#  4705/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6886342212863479042.jpeg
#  4707/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6932628407171812614.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6964864826002722054.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6939677292838849797.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7175256999448317189.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7275329832492305669.jpeg
#  4713/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7221435324986150171.jpeg
#  4715/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7145576366744947973.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7087470868879772954.jpeg
#  4719/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7183896007095094554.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7086868948578241797.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7278845659548175621.jpeg
#  4723/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7089475871450483973.jpeg
#  4731/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7129503179590421806.jpeg
#  4733/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6719479260559576325.jpeg
#  4738/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6931796084708756742.jpeg
#  4740/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6954084943374961926.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7250058307040251163.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6971419417506761990.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6931800163287567621.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7129681524139576603.jpeg
#  4749/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7125512171152313642.jpeg
#  4765/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7165474601366244654.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7220374639141260550.jpeg
#  4772/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7090851137082952966.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7189209782744567046.jpeg
#  4775/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7266668668938046725.jpeg
#  4783/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7064162687273422086.jpeg
#  4785/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6961817182061808902.jpeg
#  4790/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7009464306576231707.jpeg
#  4793/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\6952203210035776774.jpeg
#  4797/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7052316169331674374.jpeg
#  4799/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7179996440268213509.jpeg
#  4814/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7129594720342379819.jpeg
#  4818/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7187577355576151342.jpeg
#  4824/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\savetheplanet\savetheplanet Bilder Annika und Philipp\7016030314430516485.jpeg
#  4829/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7189066191573437739.jpeg
#  4834/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7126724120636575019.jpeg
#  4852/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\6827719535425064197.jpeg
#  4859/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7029818861381815558.jpeg
#  4863/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7129972995224767749.jpeg
#  4881/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7254576024434789638.jpeg
#  4900/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7122169149056388394.jpeg
#  4911/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\6952922956448156933.jpeg
#  4921/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7087812355786067205.jpeg
#  4924/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7000327691199089922.jpeg
#  4929/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7086664375704014086.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7126889807883586822.jpeg
#  4932/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7086648828329200922.jpeg
#  4939/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7087011446055292166.jpeg
#  4947/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\6996475388591443206.jpeg
#  4958/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7086926214098652421.jpeg
#  4992/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\6976351769177738502.jpeg
#  5004/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7313987219591548192.jpeg
#  5010/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7087691472820030725.jpeg
#  5014/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7286840980962168070.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\6803555409027271941.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7086895023085636870.jpeg
#  5018/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7078307986111745286.jpeg
#  5036/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7211210356083969286.jpeg
#  5046/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7106298800205073669.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7181789386797747461.jpeg
#  5061/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7244203518037478682.jpeg
#  5063/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\6932316345291918597.jpeg
#  5072/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7257124272898903322.jpeg
#  5084/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7087025653664550149.jpeg
#  5088/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7187648004734684458.jpeg
#  5091/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7049462384452193541.jpeg
#  5099/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7088388759166766338.jpeg
#  5102/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\6998801644842470658.jpeg
#  5122/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7166753804510072106.jpeg
#  5124/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7189355586050411819.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\6981887998455581958.jpeg
#  5129/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7144836427384196357.jpeg
#  5132/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7086487162186763546.jpeg
#  5138/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\6948235104703483142.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7086620139415801114.jpeg
#  5146/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7131674639683702022.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7025728069487070511.jpeg
#  5154/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7182548627858918662.jpeg
#  5158/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7030861978834947334.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7113138060472143109.jpeg
#  5162/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7108559262988766470.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7130940066339294470.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7165870209566248198.jpeg
#  5166/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7206786726780767534.jpeg
#  5171/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7086609503877205254.jpeg
#  5173/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7127056737361759493.jpeg
#  5175/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7086469589516799259.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7131338945975143686.jpeg
#  5178/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7157332928912051461.jpeg
#  5183/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\6981969386559048966.jpeg
#  5191/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7023807232890457349.jpeg
#  5201/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7246695503553973530.jpeg
#  5207/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7227482909513534766.jpeg
#  5217/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\6953946323649301766.jpeg
#  5226/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\6996294486456405254.jpeg
#  5239/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7024172007478824238.jpeg
#  5259/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\6979358927339130118.jpeg
#  5268/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7024486820411002158.jpeg
#  5275/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7252932328182336773.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7112318145309838597.jpeg
#  5278/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\6847464989788294405.jpeg
#  5282/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\6908862189994560773.jpeg
#  5286/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\6877411732243893510.jpeg
#  5292/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7080158359831383342.jpeg
#  5321/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7140009499821083910.jpeg
#  5331/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7286701370722258184.jpeg
#  5337/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7245394646040333614.jpeg
#  5341/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7230577151836163354.jpeg
#  5359/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7107230251641539846.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7315655085982338350.jpeg
#  5408/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7302810070402813217.jpeg
#  5411/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7273209801700576517.jpeg
#  5414/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatecrisis\climatecrisis Bilder philipp und Annika\7189269546526887214.jpeg
#  5419/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\6910639272555105538.jpeg
#  5437/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7087313644219911450.jpeg
#  5439/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7207885697057934598.jpeg
#  5466/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7146900341810810139.jpeg
#  5473/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7131674639683702022.jpeg
#  5484/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7085892380825554182.jpeg
#  5491/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7130665845323320581.jpeg
#  5502/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7086539216833858843.jpeg
#  5508/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7265484798125280517.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\6847464989788294405.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\6928502521191222534.jpeg
#  5512/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7236331230831152410.jpeg
#  5522/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7022383543632350469.jpeg
#  5532/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7134191844258336026.jpeg
#  5542/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7182548627858918662.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7003341995661954309.jpeg
#  5550/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7260632795893058859.jpeg
#  5552/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\6840073279743495429.jpeg
#  5561/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7133267994708577582.jpeg
#  5565/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7087942082547010842.jpeg
#  5573/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7113138060472143109.jpeg
#  5580/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7130940066339294470.jpeg
#  5589/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7086652997240900891.jpeg
#  5595/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7206786726780767534.jpeg
#  5599/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7139116818165222662.jpeg
#  5621/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7162041665744588033.jpeg
#  5635/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\6920308310419705093.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7086771116710104347.jpeg
#  5638/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7127056737361759493.jpeg
#  5648/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7087358919755959557.jpeg
#  5652/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\6749977931591765254.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\6928823827732466949.jpeg
#  5656/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7086531446239694107.jpeg
#  5659/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\6945179463063850245.jpeg
#  5662/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7211006467661466886.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7085951194056723758.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7263686327630089478.jpeg
#  5666/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7086469589516799259.jpeg
#  5668/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7205246807549529350.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7083198253465898283.jpeg
# No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7131338945975143686.jpeg
#  5674/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7087234797105319173.jpeg
#  5679/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7119540362322005254.jpeg
#  5681/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7157332928912051461.jpeg
#  5685/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7189729662032006442.jpeg
#  5691/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\6936262585993940230.jpeg
#  5711/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7016030314430516485.jpeg
#  5721/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7208151518296444165.jpeg
#  5734/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7297262468194159878.jpeg
#  5742/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7272310674821270790.jpeg
#  5758/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7168367344413117739.jpeg
#  5769/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7270865187987787054.jpeg
#  5772/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7138812326433754373.jpeg
#  5780/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7234926540490870042.jpeg
#  5788/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7257660236616551707.jpeg
#  5792/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7182521611197762821.jpeg
#  5802/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\6997713510331403547.jpeg
#  5804/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7015966998676950278.jpeg
#  5810/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7159544220821245189.jpeg
#  5816/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7143344050417077509.jpeg
#  5839/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7318540529111698731.jpeg
#  5844/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7230093787769359622.jpeg
#  5850/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7232496771220442370.jpeg
#  5864/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7314139779824635166.jpeg
#  5882/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7203830439528647942.jpeg
#  5908/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7090264334495960326.jpeg
#  5921/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7189269546526887214.jpeg
#  5944/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7317966258505387270.jpeg
#  5959/5968No File at DATA\Daten TikTok gemerged\TikTok Bilder gemerged\climatechange\climatechange Bilder Annika und Philipp\7283289341714025770.jpeg
#  5968/5968

# %%
print(len(list(df_clusters["id"].unique())))
print(df_clusters)
# Out:
# 5809
#                      id   platform        hashtag         r         g  \
# 0   7172368921318657322     tiktok  climatechange  0.956863  0.589127
# 0   7172368921318657322     tiktok  climatechange  0.513725  0.301694
# 0   7172368921318657322     tiktok  climatechange  0.650980  0.419931
# 0   7172368921318657322     tiktok  climatechange  0.876471  0.521636
# 0   7172368921318657322     tiktok  climatechange  0.776471  0.133979
# ..                  ...        ...            ...       ...       ...
# 0   klimaschutz_700.jpg  instagram    klimaschutz  0.455785  0.741176
# 0   klimaschutz_700.jpg  instagram    klimaschutz  0.703391  0.776471
# 0   klimaschutz_700.jpg  instagram    klimaschutz  0.349865  0.509804
# 0   klimaschutz_700.jpg  instagram    klimaschutz  0.000000  0.270588
# 0   klimaschutz_700.jpg  instagram    klimaschutz  0.216809  0.415686
#
#            b         h         s         v  relative_frequency
# 0   0.063791  0.098039  0.933333  0.956863            0.005642
# 0   0.227651  0.043137  0.556863  0.513725            0.006402
# 0   0.250181  0.070588  0.615686  0.650980            0.021701
# 0   0.206228  0.078431  0.764706  0.876471            0.018012
# 0   0.270036  0.964706  0.827451  0.776471            0.004774
# ..       ...       ...       ...       ...                 ...
# 0   0.119170  0.243137  0.839216  0.741176            0.011414
# 0   0.703391  0.333333  0.094118  0.776471            0.138794
# 0   0.349865  0.333333  0.313725  0.509804            0.003906
# 0   0.000000  0.333333  1.000000  0.270588            0.805786
# 0   0.216809  0.333333  0.478431  0.415686            0.040100
#
# [68666 rows x 10 columns]

# %%
df_coarse_clusters = pd.DataFrame(columns = ["id", "platform", "hashtag", "r", "g", "b", "h", "s", "v", "relative_frequency"])

# %%
#parameters for mean-shift-clustering

use_hsv = True

bin_seeding = True
bandwidth = None
if use_hsv:
    bandwidth = cluster.estimate_bandwidth(df_clusters[["h", "s", "v"]])
else:
    bandwidth = cluster.estimate_bandwidth(df_clusters[["r", "g", "b"]])

bandwidth = bandwidth /2

# %% [markdown]
# ### Meta-Clustering: Clustern der Cluster, um ähnliche Farben zusammenzubringen

# %%
#performs mean-shift clustering on the different colors found in the first step

for id in df_clusters["id"].unique():
    print(id)
    colors_in_image = df_clusters.loc[df_clusters["id"]==id]

    color_values = None
    if use_hsv:
        color_values = colors_in_image[["h", "s", "v"]]
    else:
        color_values = colors_in_image[["r", "g", "b"]]
    
    model = cluster.MeanShift(bandwidth=bandwidth, bin_seeding=bin_seeding)
    labels = model.fit_predict(color_values)
    unique_labels = np.unique(labels)
    
    print(labels)
    centroids = np.empty((unique_labels.shape[0], 3))
    relative_frequencies = np.empty((unique_labels.shape[0]))
    for i, label in enumerate(unique_labels):
        #centroids[i] = img_pixels[labels == label].mean(axis=0)
        centroids[i] = np.median(color_values[labels == label], axis=0)
        rows_with_label = colors_in_image[labels == label]
    
    #visualization stuff
    pie_colors = []
    for i, clr in enumerate(centroids):
        pie_color = tuple(clr)
        if use_hsv:
            pie_color = colorsys.hsv_to_rgb(*pie_color)
        pie_colors.append(pie_color)

    plt.pie(relative_frequencies, colors=pie_colors)
    plt.show()
    # end visualization stuff
    #print(labels)
    #print(model.cluster_centers_)
    print(f"RELATIVE FREQUENCIES:\n{relative_frequencies}")
    print(f"CENTROIDS:\n{centroids}")
    print("\n")

# %%
output_path = "fine_clusters.csv"
df_clusters.to_csv(output_path, sep=";")
