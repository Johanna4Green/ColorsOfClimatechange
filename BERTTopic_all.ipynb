# %% [markdown]
# # BERTopic

# %% [markdown]
# In this notebook all 12 dataframes (TikTok and Instagram) are combined into 1 to then get uniquely Topics for all of the datapoints. The plan is to add the topic to each row of the big dataframe and all the Words BERTopic assocciates with this topic of this datarow. Then the 12 dataframes should be split up again in the individual ones.
#
#
# The `bertopic` package for transformer based topic modeling is used.
#
#  Documentation: https://maartengr.github.io/BERTopic/index.html and a tutorial notebook: https://github.com/MaartenGr/BERTopic/blob/master/notebooks/BERTopic.ipynb
#
#
# Paper: Grootendorst, Maarten: "BERTopic: Neural topic modeling with a class-based TF-IDF procedure", arXiv preprint arXiv:2203.05794, 2022.
#
#
# Part of Michael Achmann's Notebook are used:
# ```
# Michael Achmann. (2023). michaelachmann/social-media-lab: 2023-12-04 (v0.0.6). Zenodo. https://doi.org/10.5281/zenodo.8199901
# ```

# %% [markdown]
# ##Steps:
#
# 1. Merge the 12 data frames into one big data frame using pandas' concat function.
# 2. Perform BERTopic analysis on the combined data frame to obtain topics and associated words for each row.
# 3. Add the BERTopic and BERT words columns to the combined data frame.
# 4. Merge the updated information back into the original 12 data frames using the unique IDs.

# %% [markdown]
# ### 1. Create one big dataframe
#
# 1. Access all 12 dataframes
# 2. Concat their ids, descriptions (Instagram), OCRs (Instagram), body (TikTok) columns into one new dataframe

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# INSTAGRAM
df_insta_climatecrisis = pd.read_csv('/content/drive/MyDrive/Klimawandel Projekt/Daten/INSTA_DATA_COMPLETE/climatecrisis.csv')
df_insta_climatechange = pd.read_csv('/content/drive/MyDrive/Klimawandel Projekt/Daten/INSTA_DATA_COMPLETE/climatechange.csv')
df_insta_savetheplanet = pd.read_csv('/content/drive/MyDrive/Klimawandel Projekt/Daten/INSTA_DATA_COMPLETE/savetheplanet.csv')
df_insta_klimakrise = pd.read_csv('/content/drive/MyDrive/Klimawandel Projekt/Daten/INSTA_DATA_COMPLETE/klimakrise.csv')
df_insta_klimawandel = pd.read_csv('/content/drive/MyDrive/Klimawandel Projekt/Daten/INSTA_DATA_COMPLETE/klimawandel.csv')
df_insta_klimaschutz = pd.read_csv('/content/drive/MyDrive/Klimawandel Projekt/Daten/INSTA_DATA_COMPLETE/klimaschutz.csv')

#TIKTOK
df_tiktok_climatecrisis = pd.read_csv('/content/drive/MyDrive/Klimawandel Projekt/Daten/TikTok_DATA_COMPLETE/tiktok_climatecrisis_ende.csv')
df_tiktok_climatechange = pd.read_csv('/content/drive/MyDrive/Klimawandel Projekt/Daten/TikTok_DATA_COMPLETE/tiktok_climatechange_ende.csv')
df_tiktok_savetheplanet = pd.read_csv('/content/drive/MyDrive/Klimawandel Projekt/Daten/TikTok_DATA_COMPLETE/tiktok_savetheplanet_ende.csv')
df_tiktok_klimakrise = pd.read_csv('/content/drive/MyDrive/Klimawandel Projekt/Daten/TikTok_DATA_COMPLETE/tiktok_klimakrise_ende.csv')
df_tiktok_klimawandel = pd.read_csv('/content/drive/MyDrive/Klimawandel Projekt/Daten/TikTok_DATA_COMPLETE/tiktok_klimawandel_ende.csv')
df_tiktok_klimaschutz = pd.read_csv('/content/drive/MyDrive/Klimawandel Projekt/Daten/TikTok_DATA_COMPLETE/tiktok_klimaschutz_ende.csv')

# %%
df_insta_climatecrisis.head(2)

# %%
df_tiktok_climatecrisis.head(2)

# %% [markdown]
# Only keep id and ocr and description of instagram dfs.

# %%
# this code needs to be run 6 times
# INSTAGRAM

# Creating a dataframe only for the Description
df_description = df_insta_klimawandel[['Id', 'Description']].copy() # do this for all 6 Insta_df!

# Renaming column
df_description.rename(columns={'Description': 'Text'}, inplace=True)

# Adding 'Text Type' column
df_description['Text Type'] = 'Caption'

new_df = df_description

# Dropping any rows where 'Text' is NaN or empty
new_df.dropna(subset=['Text'], inplace=True)
new_df = new_df[new_df['Text'].str.strip() != '']

# Resetting the index
new_df.reset_index(drop=True, inplace=True)

# %%
# only with the first of six csv: then only append to the all_insta
all_insta= new_df

# %%
# do this 5 times for the 5 other csvs
all_insta = pd.concat([all_insta, new_df], ignore_index=True)

# %%
len(all_insta)
# Out:
# 3802

# %%
all_insta[300:3505]
# Out:
#                        Id                                               Text  \
# 3500  klimaschutz_163.jpg  Danke an @ingwar.pero⁠\n.⁠\n.⁠\n.⁠\n#klimaschu...
# 3501  klimaschutz_164.jpg  Am einen Tag kleben sie auf der Straße, am and...
# 3502  klimaschutz_165.jpg  Deutschland ist einer Analyse des Forschungsin...
# 3503  klimaschutz_166.jpg  Streit zwischen ÖVP und Grünen: Dass sich Nied...
# 3504  klimaschutz_167.jpg  Ja zum Klimaschutz-Gesetz: 59.1 Prozent der St...
#
#      Text Type
# 3500   Caption
# 3501   Caption
# 3502   Caption
# 3503   Caption
# 3504   Caption

# %%
# save for later
all_insta.to_csv("BERTopic_Insta_DataPREP_onlyDescription.csv")

# %% [markdown]
# Only keep id and body of tiktok dfs.

# %%
# this code needs to be run 6 times
# TIKTOK

# Creating a separate dataframe
df_body = df_tiktok_klimaschutz[['id', 'body']].copy()  # do this for all 6 tiktok dfs

# Renaming columns
df_body.rename(columns={'body': 'Text', 'id': "Id"}, inplace=True)

# Adding 'Text Type' column
df_body['Text Type'] = 'Caption'

new_df = df_body


# Dropping any rows where 'Text' is NaN or empty
new_df.dropna(subset=['Text'], inplace=True)
new_df = new_df[new_df['Text'].str.strip() != '']

# Resetting the index
new_df.reset_index(drop=True, inplace=True)
print(new_df)
# Out:
#                       Id                                               Text  \
# 0    7229641670344690970  Dürfen Kinder keine Bedürfnisse äußern? #kinde...
# 1    6971355508833864965  #Rassismus in den #Medien #Fridaysforfuture #K...
# 2    7095428402261282053  Hey Leute, ich hab in dem Video paar Tipps zum...
# 3    7313149913834032416  Fidnest du die strafe angemessen? #klimakleber...
# 4    7280502024813251872  Klima-Krise erklärt in 23 Sekunden! #klima #kl...
# ..                   ...                                                ...
# 556  7099500572104985861  Doch beim Second-Hand Kauf fällt all das weg, ...
# 557  7276326619596344608  Quelle:Hr Fernsehen maintower #notarzt #notdie...
# 558  7187443510562393350  Was geht ab in Lützerath? 🏚 ➡️ Aktivisten habe...
# 559  7267819656864435488  Die #Nutztierhaltung ist haupttreiber der #Umw...
# 560  7050114244121054470  Was würdest du tun?!🤯 Drück das Plus weg!#Klim...
#
#     Text Type
# 0     Caption
# 1     Caption
# 2     Caption
# 3     Caption
# 4     Caption
# ..        ...
# 556   Caption
# 557   Caption
# 558   Caption
# 559   Caption
# 560   Caption
#
# [561 rows x 3 columns]

# %%
# only run for the first tiktok csv
all_tiktok = new_df

# %%
# then run 5x to append the other 5 tiktok dfs
all_tiktok = pd.concat([all_tiktok, new_df], ignore_index=True)

# %%
len(all_tiktok)
# Out:
# 3103

# %%
all_tiktok.head(3)
# Out:
#                     Id                                               Text  \
# 0  7197008454655937798  Tackling the climate crisis starts with realis...
# 1  6992513609523891462  ways to combat the climate crisis 💚 #foryou #c...
# 2  7104514452074007813  climate change says hello 👋🏻💀 #singer #climate...
#
#   Text Type
# 0   Caption
# 1   Caption
# 2   Caption

# %%
 # save tiktok df
all_tiktok.to_csv("BERTopic_TikTok_DataPREP.csv")

# %%
# concat insta and tiktok dfs
allData_df = pd.concat([all_insta, all_tiktok], ignore_index=True)

# %%
# save the complete df
allData_df.to_csv("BERTopic_allDataPREP.csv")

# %% [markdown]
# ### 2. BERTopic analysis
#
# Perform BERTopic analysis on the combined data frame to obtain topics and associated words for each row.

# %%
# !pip install -q bertopic
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 14.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 9.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 11.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 5.8 MB/s eta 0:00:00
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Building wheel for umap-learn (setup.py) ... done

# %%
from bertopic import BERTopic

# %% [markdown]
# In the following cells we download a stopword dictionary for the German language and applied it according to [the documentation](https://maartengr.github.io/BERTopic/faq.html#how-do-i-remove-stop-words)

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')

STOPWORDS = stopwords.words('english') + stopwords.words('spanish') + stopwords.words('italian') + stopwords.words('german')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer_model = CountVectorizer(ngram_range=(1, 2), stop_words=STOPWORDS)

# %% [markdown]
# Now we're ready to create our corpus in `docs`, a list of text documents to pass to `BERTopic`.

# %%
docs = all_data_df["Text"]

# %%
print(docs)
# Out:
# 0       Not your typical ice cube. 🧊\n\nAlthough it is...
# 1       Not your typical ice cube. 🧊\n\nAlthough it is...
# 2       2023 will be the hottest year recorded in hist...
# 3       I just know someone would try drinking them to...
# 4       According to one professor, we can stop global...
#                               ...
# 6900    Doch beim Second-Hand Kauf fällt all das weg, ...
# 6901    Quelle:Hr Fernsehen maintower #notarzt #notdie...
# 6902    Was geht ab in Lützerath? 🏚 ➡️ Aktivisten habe...
# 6903    Die #Nutztierhaltung ist haupttreiber der #Umw...
# 6904    Was würdest du tun?!🤯 Drück das Plus weg!#Klim...
# Name: Text, Length: 6905, dtype: object

# %%
# We're dealing with German and English texts, therefore we choose 'multilingual'
topic_model = BERTopic(language="multilingual", calculate_probabilities=True, verbose=True, vectorizer_model=vectorizer_model)
topics, probs = topic_model.fit_transform(docs)
# Out:
# 2024-03-06 16:11:54,786 - BERTopic - Embedding - Transforming documents to embeddings.
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.12k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/216 [00:00<?, ?it/s]
# 2024-03-06 16:22:03,351 - BERTopic - Embedding - Completed ✓
# 2024-03-06 16:22:03,354 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-03-06 16:22:48,872 - BERTopic - Dimensionality - Completed ✓
# 2024-03-06 16:22:48,875 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-03-06 16:22:56,219 - BERTopic - Cluster - Completed ✓
# 2024-03-06 16:22:56,241 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-03-06 16:23:00,201 - BERTopic - Representation - Completed ✓

# %% [markdown]
# #### Topic Visualization and Reduction

# %% [markdown]
# Now that the model is fitted, the topics are presented, and reduced to a number that can be dealt with. Then the Topics are named and then added to the all_data_df in a new Column BERTopic.
#
# We look at the most frequent topics first as they best represent the collection of documents.

# %%
freq = topic_model.get_topic_info(); freq
# Out:
#     Topic  Count                                               Name  \
# 0      -1   2714  -1_klimawandel_klimaschutz_climatechange_klima...
# 1       0   2447  0_klimaschutz_klimawandel_klimakrise_climatech...
# 2       1    279                     1_savetheplanet_pa_pa pa_viral
# 3       2    165                   2_ice_gletscher_schnee_antarktis
# 4       3    157                    3_heat_record_temperatures_grad
# 5       4    146                      4_congo_kinder_people_climate
# 6       5    142                            5_oil_shell_willow_stop
# 7       6    116            6_penguins_daisygilardini_coral_penguin
# 8       7    109       7_city_cities_carfree_carsdestroyedourcities
# 9       8     96                      8_wald_bäume_tree_klimawandel
# 10      9     96                          9_wasser_water_dürre_lake
# 11     10     84                        10_meat_fleisch_vegan_dairy
# 12     11     78                     11_maui_wildfires_fires_canada
# 13     12     62  12_sunmoney_makemoney_makemoney savetheplanet_...
# 14     13     58         13_plastic_waste_plasticfree_savetheplanet
# 15     14     54     14_thunberg_greta_greta thunberg_gretathunberg
# 16     15     38              15_amazonas_indigenous_regenwald_lula
# 17     16     33                     16_lützerath_räumung_rwe_innen
# 18     17     20  17_trashmaid_thelittletrashmaid_mermaid_thelit...
# 19     18     11    18_wildlifephotographer_eleph ants7_eleph_ants7
#
#                                    CustomName  \
# 0     klimawandel, klimaschutz, climatechange
# 1        klimaschutz, klimawandel, klimakrise
# 2                    savetheplanet, pa, pa pa
# 3                      ice, gletscher, schnee
# 4                  heat, record, temperatures
# 5                       congo, kinder, people
# 6                          oil, shell, willow
# 7             penguins, daisygilardini, coral
# 8                       city, cities, carfree
# 9                           wald, bäume, tree
# 10                       wasser, water, dürre
# 11                       meat, fleisch, vegan
# 12                     maui, wildfires, fires
# 13  sunmoney, makemoney, makemoney savethepla
# 14                plastic, waste, plasticfree
# 15            thunberg, greta, greta thunberg
# 16            amazonas, indigenous, regenwald
# 17                    lützerath, räumung, rwe
# 18     trashmaid, thelittletrashmaid, mermaid
# 19   wildlifephotographer, eleph ants7, eleph
#
#                                        Representation  \
# 0   [klimawandel, klimaschutz, climatechange, klim...
# 1   [klimaschutz, klimawandel, klimakrise, climate...
# 2   [savetheplanet, pa, pa pa, viral, foryou, fyp,...
# 3   [ice, gletscher, schnee, antarktis, arktis, kl...
# 4   [heat, record, temperatures, grad, temperature...
# 5   [congo, kinder, people, climate, help, 000, tu...
# 6   [oil, shell, willow, stop, project, climate, a...
# 7   [penguins, daisygilardini, coral, penguin, spe...
# 8   [city, cities, carfree, carsdestroyedourcities...
# 9   [wald, bäume, tree, klimawandel, forests, land...
# 10  [wasser, water, dürre, lake, drought, regen, r...
# 11  [meat, fleisch, vegan, dairy, ernährung, anima...
# 12  [maui, wildfires, fires, canada, fire, wildfir...
# 13  [sunmoney, makemoney, makemoney savetheplanet,...
# 14  [plastic, waste, plasticfree, savetheplanet, r...
# 15  [thunberg, greta, greta thunberg, gretathunber...
# 16  [amazonas, indigenous, regenwald, lula, amazon...
# 17  [lützerath, räumung, rwe, innen, polizei, brau...
# 18  [trashmaid, thelittletrashmaid, mermaid, theli...
# 19  [wildlifephotographer, eleph ants7, eleph, ant...
#
#                                   Representative_Docs
# 0   [#repost from @theslowfactory The atrocities a...
# 1   [#klima #klimawandel #klimakrise #klimakatastr...
# 2   [I have released all my dreams\n\n#surrealism ...
# 3   [Selbst in der ewigen Antarktis ist der Klimaw...
# 4   [Global temperatures in July and August were a...
# 5   [Father holds the hand of his 15-year-old daug...
# 6   [#StopWillow || This week is our last chance t...
# 7   [Photo by @daisygilardini / Chinstrap penguins...
# 8   [One of the most successful freeway removal pr...
# 9   [🇩🇪 Klimawandel und Naturschutz \n\nDer Klimaw...
# 10  [Wassermangel in gemäßigten Klimazonen? Das ka...
# 11  [Should meat be packaged like cigarettes in or...
# 12  [The government has proven time and time again...
# 13  [“SunMoney Solar Group has stood at the forefr...
# 14  [Plastic is harming people’s health, accelerat...
# 15  [Die schwedische Klimaaktivistin Greta Thunber...
# 16  [Brazil’s new president, Lula, has put Indigen...
# 17  [Gerade beginnt die Räumung des Dorfs Lützerat...
# 18  [Loose screws part 2🐠🧨\n\nRead the comic on #W...
# 19  [Newborn baby elephant🥰🥰 👉\n\nWhat is your fav...

# %%
len(freq)   # at first it was 141, it was then reduced to 20
# Out:
# 20

# %%
freq.to_csv('freq.csv', index=False) # to save the topic info in another df

# %%
#this was used to reduce the topics to 20, all the Visualisations where run before and after.
topic_model.reduce_topics(docs, nr_topics=20)
# Out:
# 2024-03-06 16:27:05,322 - BERTopic - Topic reduction - Reducing number of topics
# 2024-03-06 16:27:09,363 - BERTopic - Topic reduction - Reduced number of topics from 141 to 20

# %% [markdown]
# -1 refers to all outliers and should typically be ignored. Next, let's take a look at a frequent topic that were generated:

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a498d266-edb6-42d7-b3ad-36e2d60a302b" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a498d266-edb6-42d7-b3ad-36e2d60a302b")) {                    Plotly.newPlot(                        "a498d266-edb6-42d7-b3ad-36e2d60a302b",                        [{"customdata":[[0,"klimaschutz | klimawandel | klimakrise | climatechange | klima",2447],[1,"savetheplanet | pa | pa pa | viral | foryou",279],[2,"ice | gletscher | schnee | antarktis | arktis",165],[3,"heat | record | temperatures | grad | temperature",157],[4,"congo | kinder | people | climate | help",146],[5,"oil | shell | willow | stop | project",142],[6,"penguins | daisygilardini | coral | penguin | species",116],[7,"city | cities | carfree | carsdestroyedourcities | bancar",109],[8,"wald | b\u00e4ume | tree | klimawandel | forests",96],[9,"wasser | water | d\u00fcrre | lake | drought",96],[10,"meat | fleisch | vegan | dairy | ern\u00e4hrung",84],[11,"maui | wildfires | fires | canada | fire",78],[12,"sunmoney | makemoney | makemoney savetheplanet | solar | sdbn",62],[13,"plastic | waste | plasticfree | savetheplanet | reuse",58],[14,"thunberg | greta | greta thunberg | gretathunberg | polizei",54],[15,"amazonas | indigenous | regenwald | lula | amazon",38],[16,"l\u00fctzerath | r\u00e4umung | rwe | innen | polizei",33],[17,"trashmaid | thelittletrashmaid | mermaid | thelittletrashmaid trashmaid | mermaid savetheplanet",20],[18,"wildlifephotographer | eleph ants7 | eleph | ants7 | bio eleph",11]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[2447,279,165,157,146,142,116,109,96,96,84,78,62,58,54,38,33,20,11],"sizemode":"area","sizeref":1.529375,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[14.493528366088867,16.20612335205078,13.83508014678955,15.706951141357422,13.922205924987793,14.370659828186035,13.611163139343262,15.038186073303223,15.919407844543457,13.950484275817871,13.289788246154785,14.398009300231934,14.597978591918945,13.549047470092773,14.88587760925293,16.178871154785156,13.948892593383789,16.644298553466797,16.131437301635742],"xaxis":"x","y":[13.049209594726562,9.415800094604492,9.267949104309082,10.829813003540039,11.831860542297363,10.470296859741211,8.971949577331543,11.16635513305664,12.351033210754395,11.130271911621094,11.237430572509766,12.7645845413208,11.42366886138916,12.27724838256836,12.271862983703613,12.11568546295166,12.632177352905273,9.331363677978516,9.132450103759766],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0. ...

# %%
topic_model.get_topic(0)  # Select the most frequent topic
# Out:
# [('klimaschutz', 0.01499402919947828),
#  ('klimawandel', 0.013647721124402159),
#  ('klimakrise', 0.013107535636366222),
#  ('climatechange', 0.010022381424719678),
#  ('klima', 0.009721155766507781),
#  ('climate', 0.008749924084627238),
#  ('climatecrisis', 0.008112924358257629),
#  ('mehr', 0.007935651288609073),
#  ('deutschland', 0.007247855910014634),
#  ('fyp', 0.005912089484850443)]

# %%
topic_model.visualize_barchart(top_n_topics=20)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6c0c8fc2-756c-412b-a719-b140f7393a35" class="plotly-graph-div" style="height:1250px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c0c8fc2-756c-412b-a719-b140f7393a35")) {                    Plotly.newPlot(                        "6c0c8fc2-756c-412b-a719-b140f7393a35",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.009721155766507781,0.010022381424719678,0.013107535636366222,0.013647721124402159,0.01499402919947828],"y":["klima  ","climatechange  ","klimakrise  ","klimawandel  ","klimaschutz  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.013697239587691737,0.01450451317290469,0.02178773954641259,0.024323700128328022,0.03298163691728023],"y":["foryou  ","viral  ","pa pa  ","pa  ","savetheplanet  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.01342320181992878,0.014130599038045626,0.01569256164767539,0.024980548096398807,0.030625698847941227],"y":["arktis  ","antarktis  ","schnee  ","gletscher  ","ice  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.019165664713286092,0.019202084262199468,0.019927999480406338,0.020103827208597214,0.02278786102206442],"y":["temperature  ","grad  ","temperatures  ","record  ","heat  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.01135484547345915,0.012139560015919908,0.014374761972706514,0.014949162307079374,0.01587162791107896],"y":["help  ","climate  ","people  ","kinder  ","congo  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.016161965554932548,0.01879827136784207,0.019685913915895973,0.024674020407900045,0.037319831821442315],"y":["project  ","stop  ","willow  ","shell  ","oil  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.010418488133105398,0.010607132691435673,0.011284103566030382,0.011729809025872045,0.015179843477939742],"y":["species  ","penguin  ","coral  ","daisygilardini  ","penguins  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.024240739750489765,0.024354509974060343,0.025775711897910645,0.0287882145778678,0.03706552166213523],"y":["bancar  ","carsdestroyedourcities  ","carfree  ","cities  ","city  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.012044017844818117,0.013750307433045533,0.014391358150338384,0.017976603655768798,0.020495033380462834],"y":["forests  ","klimawandel  ","tree  ","b\u00e4ume  ","wald  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.014535103675038982,0.015023689108491082,0.019396417591533537,0.022948483968471274,0.029532328823256033],"y":["drought  ","lake  ","d\u00fcrre  ","water  ","wasser  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.013882083752348765,0.014394516135555929,0.029592704230508134,0.031028162870038095,0.04589494638049829],"y":["ern\u00e4hrung  ","dairy  ","vegan  ","fleisch  ","meat  "],"type":"bar","xaxis":"x11","yaxis":"y11"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.015822412846663986,0.016601671048361924,0.0216988874480111,0.02544009970659037,0.02738262501988871],"y":["fire  ","canada  ","fires  ","wildfires  ","maui  "],"type":"bar","xaxis":"x12","yaxis":"y12"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.04594181083222472,0.04828880931412528,0.048971235307788276,0.048971235307788276,0.10339282520531058],"y":["sdbn  ","solar  ","makemoney savetheplanet  ","makemoney  ","sunmoney  "],"type":"bar","xaxis":"x13","ya ...

# %%
# to add columns with the top 3 words of the topic
topic_labels = topic_model.generate_topic_labels(nr_words=3, topic_prefix=False, word_length=20, separator=', ')
topic_model.set_topic_labels(topic_labels)
# 2714 outliers
topic_model.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1   2714  -1_klimawandel_klimaschutz_climatechange_klima...
# 1       0   2447  0_klimaschutz_klimawandel_klimakrise_climatech...
# 2       1    279                     1_savetheplanet_pa_pa pa_viral
# 3       2    165                   2_ice_gletscher_schnee_antarktis
# 4       3    157                    3_heat_record_temperatures_grad
# 5       4    146                      4_congo_kinder_people_climate
# 6       5    142                            5_oil_shell_willow_stop
# 7       6    116            6_penguins_daisygilardini_coral_penguin
# 8       7    109       7_city_cities_carfree_carsdestroyedourcities
# 9       8     96                      8_wald_bäume_tree_klimawandel
# 10      9     96                          9_wasser_water_dürre_lake
# 11     10     84                        10_meat_fleisch_vegan_dairy
# 12     11     78                     11_maui_wildfires_fires_canada
# 13     12     62  12_sunmoney_makemoney_makemoney savetheplanet_...
# 14     13     58         13_plastic_waste_plasticfree_savetheplanet
# 15     14     54     14_thunberg_greta_greta thunberg_gretathunberg
# 16     15     38              15_amazonas_indigenous_regenwald_lula
# 17     16     33                     16_lützerath_räumung_rwe_innen
# 18     17     20  17_trashmaid_thelittletrashmaid_mermaid_thelit...
# 19     18     11    18_wildlifephotographer_eleph ants7_eleph_ants7
#
#                                    CustomName  \
# 0     klimawandel, klimaschutz, climatechange
# 1        klimaschutz, klimawandel, klimakrise
# 2                    savetheplanet, pa, pa pa
# 3                      ice, gletscher, schnee
# 4                  heat, record, temperatures
# 5                       congo, kinder, people
# 6                          oil, shell, willow
# 7             penguins, daisygilardini, coral
# 8                       city, cities, carfree
# 9                           wald, bäume, tree
# 10                       wasser, water, dürre
# 11                       meat, fleisch, vegan
# 12                     maui, wildfires, fires
# 13  sunmoney, makemoney, makemoney savethepla
# 14                plastic, waste, plasticfree
# 15            thunberg, greta, greta thunberg
# 16            amazonas, indigenous, regenwald
# 17                    lützerath, räumung, rwe
# 18     trashmaid, thelittletrashmaid, mermaid
# 19   wildlifephotographer, eleph ants7, eleph
#
#                                        Representation  \
# 0   [klimawandel, klimaschutz, climatechange, klim...
# 1   [klimaschutz, klimawandel, klimakrise, climate...
# 2   [savetheplanet, pa, pa pa, viral, foryou, fyp,...
# 3   [ice, gletscher, schnee, antarktis, arktis, kl...
# 4   [heat, record, temperatures, grad, temperature...
# 5   [congo, kinder, people, climate, help, 000, tu...
# 6   [oil, shell, willow, stop, project, climate, a...
# 7   [penguins, daisygilardini, coral, penguin, spe...
# 8   [city, cities, carfree, carsdestroyedourcities...
# 9   [wald, bäume, tree, klimawandel, forests, land...
# 10  [wasser, water, dürre, lake, drought, regen, r...
# 11  [meat, fleisch, vegan, dairy, ernährung, anima...
# 12  [maui, wildfires, fires, canada, fire, wildfir...
# 13  [sunmoney, makemoney, makemoney savetheplanet,...
# 14  [plastic, waste, plasticfree, savetheplanet, r...
# 15  [thunberg, greta, greta thunberg, gretathunber...
# 16  [amazonas, indigenous, regenwald, lula, amazon...
# 17  [lützerath, räumung, rwe, innen, polizei, brau...
# 18  [trashmaid, thelittletrashmaid, mermaid, theli...
# 19  [wildlifephotographer, eleph ants7, eleph, ant...
#
#                                   Representative_Docs
# 0   [#repost from @theslowfactory The atrocities a...
# 1   [#klima #klimawandel #klimakrise #klimakatastr...
# 2   [I have released all my dreams\n\n#surrealism ...
# 3   [Selbst in der ewigen Antarktis ist der Klimaw...
# 4   [Global temperatures in July and August were a...
# 5   [Father holds the hand of his 15-year-old daug...
# 6   [#StopWillow || This week is our last chance t...
# 7   [Photo by @daisygilardini / Chinstrap penguins...
# 8   [One of the most successful freeway removal pr...
# 9   [🇩🇪 Klimawandel und Naturschutz \n\nDer Klimaw...
# 10  [Wassermangel in gemäßigten Klimazonen? Das ka...
# 11  [Should meat be packaged like cigarettes in or...
# 12  [The government has proven time and time again...
# 13  [“SunMoney Solar Group has stood at the forefr...
# 14  [Plastic is harming people’s health, accelerat...
# 15  [Die schwedische Klimaaktivistin Greta Thunber...
# 16  [Brazil’s new president, Lula, has put Indigen...
# 17  [Gerade beginnt die Räumung des Dorfs Lützerat...
# 18  [Loose screws part 2🐠🧨\n\nRead the comic on #W...
# 19  [Newborn baby elephant🥰🥰 👉\n\nWhat is your fav...

# %%
#NOT USED
# Replace topic numbers with custom names
custom_topic_labels = []
for topic in topics:
    # Check if the topic number is within the bounds of the topic_labels list
    if topic < len(topic_labels):
        custom_topic_labels.append(topic_labels[topic])
    else:
        custom_topic_labels.append("Unknown Topic")  # Add a placeholder for out-of-bounds topics

# Add the custom topic labels to the DataFrame as a new column
all_data_df['CustomTopic'] = custom_topic_labels

# %%
# NOT USED
topics_to_merge = [-1, 0, 1]
print(topics_to_merge)
topic_model.merge_topics(docs, topics_to_merge=topics_to_merge)
topic_model.get_topic_info().head()

# %% [markdown]
# ### 3. Create Dataframe with added BERTopic Column

# %% [markdown]
# Add the BERTopic and BERT words columns to the combined data frame.

# %%
# df of docs and topic
df = pd.DataFrame({"Document": docs, "Topic": topic_model.topics_})

# %%
df
# Out:
#                                                Document  Topic
# 0     Not your typical ice cube. 🧊\n\nAlthough it is...      2
# 1     Not your typical ice cube. 🧊\n\nAlthough it is...      2
# 2     2023 will be the hottest year recorded in hist...      3
# 3     I just know someone would try drinking them to...     -1
# 4     According to one professor, we can stop global...     -1
# ...                                                 ...    ...
# 6900  Doch beim Second-Hand Kauf fällt all das weg, ...     -1
# 6901  Quelle:Hr Fernsehen maintower #notarzt #notdie...     -1
# 6902  Was geht ab in Lützerath? 🏚 ➡️ Aktivisten habe...     16
# 6903  Die #Nutztierhaltung ist haupttreiber der #Umw...     -1
# 6904  Was würdest du tun?!🤯 Drück das Plus weg!#Klim...      0
#
# [6905 rows x 2 columns]

# %%
# how many Post-Descriptions belong to each topic (-1 = Outlier Topic)
count_topic_1 = (df['Topic'] == -1).sum()
print(count_topic_1)
# Out:
# 2714

# %%
all_data_df.head()
# Out:
#    Unnamed: 0                   Id  \
# 0           0  climatechange_1.jpg
# 1           1  climatechange_2.jpg
# 2           2  climatechange_3.jpg
# 3           3  climatechange_4.jpg
# 4           4  climatechange_5.jpg
#
#                                                 Text Text Type
# 0  Not your typical ice cube. 🧊\n\nAlthough it is...   Caption
# 1  Not your typical ice cube. 🧊\n\nAlthough it is...   Caption
# 2  2023 will be the hottest year recorded in hist...   Caption
# 3  I just know someone would try drinking them to...   Caption
# 4  According to one professor, we can stop global...   Caption

# %%
# Assuming your dataframes are named all_data_df and topic_df
# Merge the dataframes based on the common column 'Document' and 'Text'
merged_df = pd.merge(all_data_df, df, left_on='Text', right_on='Document', how='left')

# Drop the extra 'Document' column and we do not need the 'Text Type' Column, as all the Text Types are Captions
merged_df.drop('Document', axis=1, inplace=True)
merged_df.drop('Text Type', axis=1, inplace=True)
# Now merged_df contains all_data_df with the 'Topic' column appended

# %%
merged_df.head()
# Out:
#    Unnamed: 0                   Id  \
# 0           0  climatechange_1.jpg
# 1           0  climatechange_1.jpg
# 2           1  climatechange_2.jpg
# 3           1  climatechange_2.jpg
# 4           2  climatechange_3.jpg
#
#                                                 Text  Topic
# 0  Not your typical ice cube. 🧊\n\nAlthough it is...      2
# 1  Not your typical ice cube. 🧊\n\nAlthough it is...      2
# 2  Not your typical ice cube. 🧊\n\nAlthough it is...      2
# 3  Not your typical ice cube. 🧊\n\nAlthough it is...      2
# 4  2023 will be the hottest year recorded in hist...      3

# %%
final_df = pd.merge(all_data_df, THISDF, left_on='Text', right_on='Document', how='left')

# %%
final_df
# Out:
#       Unnamed: 0                   Id  \
# 0              0  climatechange_1.jpg
# 1              0  climatechange_1.jpg
# 2              1  climatechange_2.jpg
# 3              1  climatechange_2.jpg
# 4              2  climatechange_3.jpg
# ...          ...                  ...
# 9184        6902  7187443510562393350
# 9185        6903  7267819656864435488
# 9186        6903  7267819656864435488
# 9187        6904  7050114244121054470
# 9188        6904  7050114244121054470
#
#                                                    Text Text Type  \
# 0     Not your typical ice cube. 🧊\n\nAlthough it is...   Caption
# 1     Not your typical ice cube. 🧊\n\nAlthough it is...   Caption
# 2     Not your typical ice cube. 🧊\n\nAlthough it is...   Caption
# 3     Not your typical ice cube. 🧊\n\nAlthough it is...   Caption
# 4     2023 will be the hottest year recorded in hist...   Caption
# ...                                                 ...       ...
# 9184  Was geht ab in Lützerath? 🏚 ➡️ Aktivisten habe...   Caption
# 9185  Die #Nutztierhaltung ist haupttreiber der #Umw...   Caption
# 9186  Die #Nutztierhaltung ist haupttreiber der #Umw...   Caption
# 9187  Was würdest du tun?!🤯 Drück das Plus weg!#Klim...   Caption
# 9188  Was würdest du tun?!🤯 Drück das Plus weg!#Klim...   Caption
#
#                                                Document  Topic  \
# 0     Not your typical ice cube. 🧊\n\nAlthough it is...      2
# 1     Not your typical ice cube. 🧊\n\nAlthough it is...      2
# 2     Not your typical ice cube. 🧊\n\nAlthough it is...      2
# 3     Not your typical ice cube. 🧊\n\nAlthough it is...      2
# 4     2023 will be the hottest year recorded in hist...      3
# ...                                                 ...    ...
# 9184  Was geht ab in Lützerath? 🏚 ➡️ Aktivisten habe...     16
# 9185  Die #Nutztierhaltung ist haupttreiber der #Umw...     -1
# 9186  Die #Nutztierhaltung ist haupttreiber der #Umw...     -1
# 9187  Was würdest du tun?!🤯 Drück das Plus weg!#Klim...      0
# 9188  Was würdest du tun?!🤯 Drück das Plus weg!#Klim...      0
#
#                                                    Name  \
# 0                      2_ice_gletscher_schnee_antarktis
# 1                      2_ice_gletscher_schnee_antarktis
# 2                      2_ice_gletscher_schnee_antarktis
# 3                      2_ice_gletscher_schnee_antarktis
# 4                       3_heat_record_temperatures_grad
# ...                                                 ...
# 9184                     16_lützerath_räumung_rwe_innen
# 9185  -1_klimawandel_klimaschutz_climatechange_klima...
# 9186  -1_klimawandel_klimaschutz_climatechange_klima...
# 9187  0_klimaschutz_klimawandel_klimakrise_climatech...
# 9188  0_klimaschutz_klimawandel_klimakrise_climatech...
#
#                                    CustomName  \
# 0                      ice, gletscher, schnee
# 1                      ice, gletscher, schnee
# 2                      ice, gletscher, schnee
# 3                      ice, gletscher, schnee
# 4                  heat, record, temperatures
# ...                                       ...
# 9184                  lützerath, räumung, rwe
# 9185  klimawandel, klimaschutz, climatechange
# 9186  klimawandel, klimaschutz, climatechange
# 9187     klimaschutz, klimawandel, klimakrise
# 9188     klimaschutz, klimawandel, klimakrise
#
#                                          Representation  \
# 0     [ice, gletscher, schnee, antarktis, arktis, kl...
# 1     [ice, gletscher, schnee, antarktis, arktis, kl...
# 2     [ice, gletscher, schnee, antarktis, arktis, kl...
# 3     [ice, gletscher, schnee, antarktis, arktis, kl...
# 4     [heat, record, temperatures, grad, temperature...
# ...                                                 ...
# 9184  [lützerath, räumung, rwe, innen, polizei, brau...
# 9185  [klimawandel, klimaschutz, climatechange, klim...
# 9186  [klimawandel, klimaschutz, climatechange, klim...
# 9187  [klimaschutz, klimawandel, klimakrise, climate...
# 9188  [klimaschutz, klimawandel, klimakrise, climate...
#
#                                     Representative_Docs  \
# 0     [Selbst in der ewigen Antarktis ist der Klimaw...
# 1     [Selbst in der ewigen Antarktis ist der Klimaw...
# 2     [Selbst in der ewigen Antarktis ist der Klimaw...
# 3     [Selbst in der ewigen Antarktis ist der Klimaw...
# 4     [Global temperatures in July and August were a...
# ...                                                 ...
# 9184  [Gerade beginnt die Räumung des Dorfs Lützerat...
# 9185  [#repost from @theslowfactory The atrocities a...
# 9186  [#repost from @theslowfactory The atrocities a...
# 9187  [#klima #klimawandel #klimakrise #klimakatastr...
# 9188  [#klima #klimawandel #klimakrise #klimakatastr...
#
#                                             Top_n_words  Probability  \
# 0     ice - gletscher - schnee - antarktis - arktis ...     0.906538
# 1     ice - gletscher - schnee - antarktis - arktis ...     1.000000
# 2     ice - gletscher - schnee - antarktis - arktis ...     0.906538
# 3     ice - gletscher - schnee - antarktis - arktis ...     1.000000
# 4     heat - record - temperatures - grad - temperat...     1.000000
# ...                                                 ...          ...
# 9184  lützerath - räumung - rwe - innen - polizei - ...     1.000000
# 9185  klimawandel - klimaschutz - climatechange - kl...     0.441703
# 9186  klimawandel - klimaschutz - climatechange - kl...     0.659057
# 9187  klimaschutz - klimawandel - klimakrise - clima...     0.350770
# 9188  klimaschutz - klimawandel - klimakrise - clima...     0.344948
#
#       Representative_document
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 9184                    False
# 9185                    False
# 9186                    False
# 9187                    False
# 9188                    False
#
# [9189 rows x 13 columns]

# %%
final_df.to_csv("all_BERTopic_Info.csv")

# %%
only_basic_bert_info = final_df

# %%
only_basic_bert_info =only_basic_bert_info.drop(["Text Type", "Topic", "Document", "CustomName", "Representation", "Representative_Docs", "Top_n_words", "Representative_document" ], axis= 1)

# %%
only_basic_bert_info = only_basic_bert_info.rename(columns={"Name": "BERTopic"})

# %%
only_basic_bert_info
# Out:
#       Unnamed: 0                   Id  \
# 0              0  climatechange_1.jpg
# 1              0  climatechange_1.jpg
# 2              1  climatechange_2.jpg
# 3              1  climatechange_2.jpg
# 4              2  climatechange_3.jpg
# ...          ...                  ...
# 9184        6902  7187443510562393350
# 9185        6903  7267819656864435488
# 9186        6903  7267819656864435488
# 9187        6904  7050114244121054470
# 9188        6904  7050114244121054470
#
#                                                    Text  \
# 0     Not your typical ice cube. 🧊\n\nAlthough it is...
# 1     Not your typical ice cube. 🧊\n\nAlthough it is...
# 2     Not your typical ice cube. 🧊\n\nAlthough it is...
# 3     Not your typical ice cube. 🧊\n\nAlthough it is...
# 4     2023 will be the hottest year recorded in hist...
# ...                                                 ...
# 9184  Was geht ab in Lützerath? 🏚 ➡️ Aktivisten habe...
# 9185  Die #Nutztierhaltung ist haupttreiber der #Umw...
# 9186  Die #Nutztierhaltung ist haupttreiber der #Umw...
# 9187  Was würdest du tun?!🤯 Drück das Plus weg!#Klim...
# 9188  Was würdest du tun?!🤯 Drück das Plus weg!#Klim...
#
#                                                BERTopic  Probability
# 0                      2_ice_gletscher_schnee_antarktis     0.906538
# 1                      2_ice_gletscher_schnee_antarktis     1.000000
# 2                      2_ice_gletscher_schnee_antarktis     0.906538
# 3                      2_ice_gletscher_schnee_antarktis     1.000000
# 4                       3_heat_record_temperatures_grad     1.000000
# ...                                                 ...          ...
# 9184                     16_lützerath_räumung_rwe_innen     1.000000
# 9185  -1_klimawandel_klimaschutz_climatechange_klima...     0.441703
# 9186  -1_klimawandel_klimaschutz_climatechange_klima...     0.659057
# 9187  0_klimaschutz_klimawandel_klimakrise_climatech...     0.350770
# 9188  0_klimaschutz_klimawandel_klimakrise_climatech...     0.344948
#
# [9189 rows x 5 columns]

# %%
only_basic_bert_info.to_csv("only_basic_BERTopic_info.csv", index = False)

# %% [markdown]
# ### 4. Add BERTopic to original 12 dataframes

# %% [markdown]
# Merge the updated information back into the original 12 data frames using the unique IDs.

# %%
# use this one so each single dataframe gets a column BERTopic appended
# with the topic number and the first three most frequent words
# of its topic
only_basic_bert_info[6010:600]
# Out:
#       Unnamed: 0                   id  \
# 6800        5028  7120666070175796485
# 6801        5029  7247679923660361006
# 6802        5030  7267702109674638638
# 6803        5031  7121966214003330310
# 6804        5032  7205676012816878891
# ...          ...                  ...
# 6895        5113  7163977121520553262
# 6896        5114  6965056820553534725
# 6897        5115  7092304430090947845
# 6898        5116  7204901930928295211
# 6899        5117  6864904431402487042
#
#                                                    Text  \
# 6800  HAT DIE KÖNIGIN ÜBERLEBT ??? @beesteez #beeste...
# 6801  Replying to @simplyburiedinbooks   How to Zero...
# 6802  Can you tell im craving mexican food?🥴🌮✨🌱🌎 #wh...
# 6803  #greenscreen #thereisnoplanetb #fyp #climatech...
# 6804  Google “stop the willow project.” Sign every p...
# ...                                                 ...
# 6895  sources: darksky.org, cescos.fau.edu #savethep...
# 6896  Für Tipps folgt mir dort gerne —> mariacmdy 😂 ...
# 6897  Parte 1#TZD_MOPA #semtags🙌 #stumbleguys #savet...
# 6898  the willow project will effect ecosystems, ani...
# 6899  The Real Cause Of The #California Wildfires #N...
#
#                                                BERTopic  Probability
# 6800                     1_savetheplanet_pa_pa pa_viral     0.352054
# 6801  -1_klimawandel_klimaschutz_climatechange_klima...     0.250891
# 6802  -1_klimawandel_klimaschutz_climatechange_klima...     0.208912
# 6803  -1_klimawandel_klimaschutz_climatechange_klima...     0.656021
# 6804  -1_klimawandel_klimaschutz_climatechange_klima...     0.378042
# ...                                                 ...          ...
# 6895  0_klimaschutz_klimawandel_klimakrise_climatech...     0.574413
# 6896  -1_klimawandel_klimaschutz_climatechange_klima...     0.399995
# 6897                     1_savetheplanet_pa_pa pa_viral     1.000000
# 6898                            5_oil_shell_willow_stop     0.592996
# 6899                     11_maui_wildfires_fires_canada     0.283915
#
# [100 rows x 5 columns]

# %% [markdown]
# For the Instagram Data:
# This needs to be done for each of the 6 dataframes.
# So replace all the names and run it 6 times.

# %%
# Merge the DataFrames based on the common column 'Id', performing a left join
merged_insta_df = pd.merge(df_insta_klimaschutz, only_basic_bert_info[['Id', 'BERTopic']], on='Id', how='left')

# %%
df_insta_klimaschutz['BERTopic'] = merged_insta_df['BERTopic']

# %%
df_insta_klimaschutz
# Out:
#                       Id                              Account       User Name  \
# 0      klimaschutz_1.jpg                           tagesschau      tagesschau
# 1      klimaschutz_2.jpg                       ZDF heute-show       heuteshow
# 2      klimaschutz_3.jpg                           tagesschau      tagesschau
# 3      klimaschutz_4.jpg                           tagesschau      tagesschau
# 4      klimaschutz_5.jpg                           tagesschau      tagesschau
# ..                   ...                                  ...             ...
# 683  klimaschutz_696.jpg                          RTL Aktuell      rtlaktuell
# 684  klimaschutz_697.jpg  AfD-Fraktion im Deutschen Bundestag  afdimbundestag
# 685  klimaschutz_698.jpg                       Jörg Spengler  joerg_spengler
# 686  klimaschutz_699.jpg                   NABU Bundesverband            nabu
# 687  klimaschutz_700.jpg               Greenpeace Deutschland   greenpeace.de
#
#      Followers at Posting              Post Created Post Created Date  \
# 0               4589981.0  2023-07-20 10:00:11 CEST          20.07.23
# 1               2169088.0   2023-01-16 15:13:19 CET          16.01.23
# 2               4798823.0   2023-12-13 18:00:32 CET          13.12.23
# 3               4480794.0  2023-04-21 17:30:06 CEST          21.04.23
# 4               4540786.0  2023-06-19 12:07:00 CEST          19.06.23
# ..                    ...                       ...               ...
# 683              471745.0  2023-05-08 14:56:29 CEST          08.05.23
# 684               51389.0  2023-05-04 11:24:43 CEST          04.05.23
# 685               11617.0   2023-11-10 06:45:16 CET          10.11.23
# 686              200623.0  2023-07-15 16:00:00 CEST          15.07.23
# 687              399056.0  2023-10-05 14:48:34 CEST          05.10.23
#
#     Post Created Time   Type Total Interactions   Likes  ...  \
# 0            10:00:11  Album            215,428  213214  ...
# 1            15:13:19  Photo            149,974  149074  ...
# 2            18:00:32  Photo            131,109  125662  ...
# 3            17:30:06  Album             129,01  124401  ...
# 4            12:07:00  Album            118,155  114588  ...
# ..                ...    ...                ...     ...  ...
# 683          14:56:29  Photo              2,518    1299  ...
# 684          11:24:43  Photo              2,511    2390  ...
# 685          06:45:16  Photo              2,501    2490  ...
# 686          16:00:00  Album              2,499    2483  ...
# 687          14:48:34  Album              2,499    2422  ...
#
#                                                  Photo  Title  \
# 0    https://scontent-sea1-1.cdninstagram.com/v/t39...    NaN
# 1    https://scontent-sea1-1.cdninstagram.com/v/t51...    NaN
# 2    https://scontent-sea1-1.cdninstagram.com/v/t39...    NaN
# 3    https://scontent-sea1-1.cdninstagram.com/v/t39...    NaN
# 4    https://scontent-sea1-1.cdninstagram.com/v/t39...    NaN
# ..                                                 ...    ...
# 683  https://scontent-sea1-1.cdninstagram.com/v/t51...    NaN
# 684  https://scontent-sea1-1.cdninstagram.com/v/t39...    NaN
# 685  https://scontent-sea1-1.cdninstagram.com/v/t51...    NaN
# 686  https://scontent-sea1-1.cdninstagram.com/v/t51...    NaN
# 687  https://scontent-sea1-1.cdninstagram.com/v/t51...    NaN
#
#                                            Description  \
# 0    Bei Reisen durch Europa ist die klimafreundlic...
# 1                                     NSFW\n#heuteshow
# 2    Die Klimaschutzgruppe Letzte Generation hat in...
# 3    Ein Tempolimit von 130 Kilometern pro Stunde i...
# 4    Um die Klimaziele zu erreichen, könnten in den...
# ..                                                 ...
# 683  Die jüngste Extremhitze in Spanien und anderen...
# 684  ❌Den grünen Sumpf austrocknen!\n \n➡Laut Medie...
# 685  Die #Klimakrise ist keine Frage des Glaubens, ...
# 686  Es ist mal wieder Zeit für ein paar Gute Nachr...
# 687  Bayern wird erst in 280 Jahren klimaneutral se...
#
#                                             Image Text Sponsor Id  \
# 0                                                  NaN        NaN
# 1    ‎outdoor, ‎'‎Porn hub 2KAufrufe ld agen RWE & ...        NaN
# 2    „Letzte Generation Weihnachtsbäüme mitFarbebes...        NaN
# 3                                                  NaN        NaN
# 4                                                  NaN        NaN
# ..                                                 ...        ...
# 683  RT Laut Studie Klimawandel macht Extremhitze 1...        NaN
# 684  Milliardengeschäft durch Enteignung Der grüne ...        NaN
# 685                                                NaN        NaN
# 686                                                NaN        NaN
# 687                                                NaN        NaN
#
#     Sponsor Name  Total Interactions (weighted  —  Likes 1x Comments 1x )  \
# 0            NaN                                            215,428
# 1            NaN                                            149,974
# 2            NaN                                            131,109
# 3            NaN                                             129,01
# 4            NaN                                            118,155
# ..           ...                                                ...
# 683          NaN                                              2,518
# 684          NaN                                              2,511
# 685          NaN                                              2,501
# 686          NaN                                              2,499
# 687          NaN                                              2,499
#
#     Overperforming Score          language  \
# 0                03. May   Language.GERMAN
# 1                 Feb 91  Language.ENGLISH
# 2                 Feb 57   Language.GERMAN
# 3                 Jan 83   Language.GERMAN
# 4                 Jan 67   Language.GERMAN
# ..                   ...               ...
# 683               Feb 28   Language.GERMAN
# 684              01. Apr   Language.GERMAN
# 685               Jan 74   Language.GERMAN
# 686                -1.26   Language.GERMAN
# 687              01. Apr   Language.GERMAN
#
#                                               BERTopic
# 0    -1_klimawandel_klimaschutz_climatechange_klima...
# 1                       1_savetheplanet_pa_pa pa_viral
# 2    0_klimaschutz_klimawandel_klimakrise_climatech...
# 3    0_klimaschutz_klimawandel_klimakrise_climatech...
# 4    -1_klimawandel_klimaschutz_climatechange_klima...
# ..                                                 ...
# 683  0_klimaschutz_klimawandel_klimakrise_climatech...
# 684  -1_klimawandel_klimaschutz_climatechange_klima...
# 685  -1_klimawandel_klimaschutz_climatechange_klima...
# 686                     1_savetheplanet_pa_pa pa_viral
# 687  0_klimaschutz_klimawandel_klimakrise_climatech...
#
# [688 rows x 25 columns]

# %%
# ACHTUNG: if execuded, csv in drive gets changed!!!
# Write the modified DataFrame back to a CSV file
#df_insta_klimaschutz.to_csv('/content/drive/MyDrive/Klimawandel Projekt/Daten/INSTA_DATA_COMPLETE/klimaschutz.csv', index=False)

# %% [markdown]
# For the TikTok Data: This needs to be done for each of the 6 dataframes. So replace all the names and run it 6 times.

# %%
only_basic_bert_info_TIKTOK = only_basic_bert_info

# %%
only_basic_bert_info_TIKTOK.rename(columns={'Id': 'id'}, inplace=True)

# %%
# Assuming your DataFrame is named df

# Use regular expressions to filter rows based on the pattern
pattern = r'^\d+$'  # This pattern matches strings containing only digits
filtered_df_for_TIKTOK = only_basic_bert_info_TIKTOK[only_basic_bert_info_TIKTOK['id'].astype(str).str.match(pattern)]

# Now filtered_df contains only the rows where the 'Id' column contains only digits

# %%
filtered_df_for_TIKTOK['id'] = filtered_df_for_TIKTOK['id'].astype(int)

# %%
len(filtered_df_for_TIKTOK)
# Out:
# 3787

# %%
#df_tiktok_klimaschutz
#df_tiktok_klimaschutz = pd.read_csv('/content/drive/MyDrive/Klimawandel Projekt/Daten/TikTok_DATA_COMPLETE/tiktok_klimaschutz_ende.csv')

# %%
# Merge the DataFrames based on the common column 'Id', performing a left join
merged_tiktok_df = pd.merge(df_tiktok_savetheplanet, filtered_df_for_TIKTOK[['id', 'BERTopic']], on='id', how='left')

# %%
df_tiktok_savetheplanet['BERTopic'] = merged_tiktok_df['BERTopic']

# %%
df_tiktok_savetheplanet

# %%
# ACHTUNG: if execuded, csv in drive gets changed!!!
# Write the modified DataFrame back to a CSV file
# df_tiktok_savetheplanet.to_csv('/content/drive/MyDrive/Klimawandel Projekt/Daten/TikTok_DATA_COMPLETE/tiktok_savetheplanet_ende.csv', index=False)
